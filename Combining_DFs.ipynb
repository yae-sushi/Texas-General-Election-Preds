# %% [markdown]
# ## Combining dataframes from group members into one dataframe

# %%
import pandas as pd

# %%
jack = pd.read_csv('Jacks_df.csv', index_col = 'Unnamed: 0')

# %%
jack['county'] = jack['county_name'].apply(lambda x: x.lower() + ' county')
index = jack['county']

# %%
jack.drop(columns = 'county_name', inplace = True)

# %%
jack.set_index('county', inplace = True)

# %%
jack.shape
# Out:
# (254, 8)

# %%
voting_nums = pd.read_csv('./data/voting_numbers.csv', index_col = 'Unnamed: 0')

# %%
voting_nums.head()
# Out:
#             county 2012_reg_voters 2012_voted_num 2012_voted_perc  \
# 0    bosque county          11,977          7,343          61.31%
# 1     brown county          22,565         13,944          61.79%
# 2   jimhogg county           3,804          1,667          43.82%
# 3    austin county          18,005         11,644          64.67%
# 4  franklin county           6,663          4,256          63.88%
#
#   2012_early_vote_num 2012_early_vote_perc 2016_reg_voters 2016_voted_num  \
# 0               2,563               21.40%          12,002          7,823
# 1               8,713               38.61%          23,424         14,018
# 2                 590               15.51%           3,942          2,119
# 3               6,046               33.58%          19,263         12,273
# 4               2,350               35.27%           6,798          4,377
#
#   2016_voted_perc 2016_early_vote_num 2016_early_vote_perc 2020_reg_voters  \
# 0          65.18%               3,898               32.48%          12,724
# 1          59.84%               9,986               42.63%          23,954
# 2          53.75%               1,331               33.76%           3,800
# 3          63.71%               7,351               38.16%          20,293
# 4          64.39%               2,746               40.39%           7,061
#
#   2020_voted_num 2020_voted_perc 2020_early_vote_num 2020_early_vote_perc
# 0          9,094          71.47%               6,535               71.86%
# 1         15,940          66.54%              12,544               78.70%
# 2          2,034          53.53%               1,444               70.99%
# 3         14,368          70.80%              11,550               80.39%
# 4          5,000          70.81%               3,938               78.76%

# %%
voting_nums.drop_duplicates(inplace = True)

# %%
voting_nums.shape
voting_nums.set_index('county', inplace = True)

# %%
voting_nums.dtypes
# Out:
# 2012_reg_voters         object
# 2012_voted_num          object
# 2012_voted_perc         object
# 2012_early_vote_num     object
# 2012_early_vote_perc    object
# 2016_reg_voters         object
# 2016_voted_num          object
# 2016_voted_perc         object
# 2016_early_vote_num     object
# 2016_early_vote_perc    object
# 2020_reg_voters         object
# 2020_voted_num          object
# 2020_voted_perc         object
# 2020_early_vote_num     object
# 2020_early_vote_perc    object
# dtype: object

# %%
voting_nums.head()
# Out:
#                 2012_reg_voters 2012_voted_num 2012_voted_perc  \
# county
# bosque county            11,977          7,343          61.31%
# brown county             22,565         13,944          61.79%
# jimhogg county            3,804          1,667          43.82%
# austin county            18,005         11,644          64.67%
# franklin county           6,663          4,256          63.88%
#
#                 2012_early_vote_num 2012_early_vote_perc 2016_reg_voters  \
# county
# bosque county                 2,563               21.40%          12,002
# brown county                  8,713               38.61%          23,424
# jimhogg county                  590               15.51%           3,942
# austin county                 6,046               33.58%          19,263
# franklin county               2,350               35.27%           6,798
#
#                 2016_voted_num 2016_voted_perc 2016_early_vote_num  \
# county
# bosque county            7,823          65.18%               3,898
# brown county            14,018          59.84%               9,986
# jimhogg county           2,119          53.75%               1,331
# austin county           12,273          63.71%               7,351
# franklin county          4,377          64.39%               2,746
#
#                 2016_early_vote_perc 2020_reg_voters 2020_voted_num  \
# county
# bosque county                 32.48%          12,724          9,094
# brown county                  42.63%          23,954         15,940
# jimhogg county                33.76%           3,800          2,034
# austin county                 38.16%          20,293         14,368
# franklin county               40.39%           7,061          5,000
#
#                 2020_voted_perc 2020_early_vote_num 2020_early_vote_perc
# county
# bosque county            71.47%               6,535               71.86%
# brown county             66.54%              12,544               78.70%
# jimhogg county           53.53%               1,444               70.99%
# austin county            70.80%              11,550               80.39%
# franklin county          70.81%               3,938               78.76%

# %%
def percent_to_float(percent):
    """
    Converts string percentage to decimal proportion
    percent - string of number ending in "%" to convert to float
    """
    return float(percent[:-1]) / 100

# %%
perc_list = ['2012_voted_perc', '2012_early_vote_perc', 
             '2016_voted_perc', '2016_early_vote_perc', 
             '2020_voted_perc', '2020_early_vote_perc']

# %%
for col in perc_list:
    voting_nums[col] = voting_nums[col].apply(percent_to_float)

# %%
for col in voting_nums.columns:
    if voting_nums[col].dtype == 'object':
        voting_nums[col] = voting_nums[col].apply(lambda x: x.replace(",", ""))
    
for col in voting_nums.columns:
    voting_nums[col] = voting_nums[col].apply(pd.to_numeric)

# %%
jack.dtypes
# Out:
# 2012_unemp                            float64
# 2016_unemp                            float64
# 2020_unemp                            float64
# 2012_var_state                        float64
# 2016_var_state                        float64
# 2020_var_state                        float64
# median_income_2012_2016_16_dollars      int64
# median_income_2020_16_dollars           int64
# dtype: object

# %%
df = jack.merge(right = voting_nums, how = 'left', left_index = True, right_index = True)

# %%
df.head()
# Out:
#                  2012_unemp  2016_unemp  2020_unemp  2012_var_state  \
# county
# anderson county       0.036       0.043       0.056          -0.029
# andrews county        0.031       0.047       0.082          -0.034
# angelina county       0.051       0.059       0.076          -0.014
# aransas county        0.068       0.056       0.085           0.003
# archer county         0.034       0.043       0.053          -0.031
#
#                  2016_var_state  2020_var_state  \
# county
# anderson county          -0.005          -0.012
# andrews county           -0.001           0.014
# angelina county           0.011           0.008
# aransas county            0.008           0.017
# archer county            -0.005          -0.015
#
#                  median_income_2012_2016_16_dollars  \
# county
# anderson county                               42146
# andrews county                                70121
# angelina county                               44185
# aransas county                                44851
# archer county                                 62407
#
#                  median_income_2020_16_dollars  2012_reg_voters  \
# county
# anderson county                          44871          26494.0
# andrews county                           69369           8271.0
# angelina county                          47917          49317.0
# aransas county                           49153          15883.0
# archer county                            59010           6322.0
#
#                  2012_voted_num  ...  2016_reg_voters  2016_voted_num  \
# county                           ...
# anderson county         16168.0  ...          28111.0         16887.0
# andrews county           4478.0  ...           9130.0          4941.0
# angelina county         28460.0  ...          51610.0         29896.0
# aransas county           9646.0  ...          17263.0         10486.0
# archer county            4163.0  ...           6314.0          4277.0
#
#                  2016_voted_perc  2016_early_vote_num  2016_early_vote_perc  \
# county
# anderson county           0.6007              10792.0                0.3839
# andrews county            0.5412               3429.0                0.3756
# angelina county           0.5793              20428.0                0.3958
# aransas county            0.6074               8421.0                0.4878
# archer county             0.6774               2284.0                0.3617
#
#                  2020_reg_voters  2020_voted_num  2020_voted_perc  \
# county
# anderson county          29274.0         19155.0           0.6543
# andrews county           10272.0          5856.0           0.5701
# angelina county          53166.0         34628.0           0.6513
# aransas county           18306.0         12241.0           0.6687
# archer county             6538.0          4796.0           0.7336
#
#                  2020_early_vote_num  2020_early_vote_perc
# county
# anderson county              14459.0                0.7548
# andrews county                4776.0                0.8156
# angelina county              28676.0                0.8281
# aransas county               10983.0                0.8772
# archer county                 3623.0                0.7554
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (254, 23)

# %%
voting_party_data = pd.read_csv('./data/voting_party_data.csv')

# %%
voting_party_data.shape
# Out:
# (254, 33)

# %%
voting_party_data.head()[:10]
# Out:
#             County 2020_rep_vote_count 2020_rep_vote_perc 2020_dem_vote_count  \
# 0  anderson county              15,110             78.59%               3,955
# 1   andrews county               4,943             84.31%                 850
# 2  angelina county              25,076             72.53%               9,143
# 3   aransas county               9,239             75.17%               2,916
# 4    archer county               4,300             89.66%                 446
#
#   2020_dem_vote_perc 2020_lib_vote_count 2020_lib_vote_perc  \
# 0             20.57%                 134              0.70%
# 1             14.50%                  60              1.02%
# 2             26.44%                 274              0.79%
# 3             23.73%                 103              0.84%
# 4              9.30%                  45              0.94%
#
#   2020_grn_vote_count 2020_grn_vote_perc 2020_oth_vote_count  ...  \
# 0                  22              0.11%                   6  ...
# 1                  10              0.17%                   0  ...
# 2                  75              0.22%                   6  ...
# 3                  31              0.25%                   1  ...
# 4                   4              0.08%                   1  ...
#
#   2012_rep_vote_perc 2012_rep_vote_count 2012_dem_vote_perc  \
# 0             75.64%              12,262             23.52%
# 1             81.19%               3,639             17.74%
# 2             71.47%              20,303             27.58%
# 3             70.79%               6,830             28.03%
# 4             86.46%               3,600             12.61%
#
#   2012_dem_vote_count 2012_oth_vote_perc 2012_oth_vote_count 2012_vote_total  \
# 0               3,813              0.85%                 137          16,212
# 1                 795              1.07%                  48           4,482
# 2               7,834              0.95%                 269          28,406
# 3               2,704              1.18%                 114           9,648
# 4                 525              0.94%                  39           4,164
#
#   2012_CWPP 2016_CWPP 2020_CWPP
# 0         0         0         0
# 1         0         0         0
# 2         0         0         0
# 3         0         1         1
# 4         0         0         1
#
# [5 rows x 33 columns]

# %%
voting_party_data.set_index('County', inplace = True)

# %%
perc_list = [col for col in voting_party_data.columns if "perc" in col]

# %%
for col in perc_list:
    voting_party_data[col] = voting_party_data[col].apply(percent_to_float)

# %%
for col in voting_party_data.columns:
    if voting_party_data[col].dtype == 'object':
        voting_party_data[col] = voting_party_data[col].apply(lambda x: x.replace(",", ""))
    
for col in voting_party_data.columns:
    voting_party_data[col] = voting_party_data[col].apply(pd.to_numeric)

# %%
voting_party_data.dtypes
# Out:
# 2020_rep_vote_count       int64
# 2020_rep_vote_perc      float64
# 2020_dem_vote_count       int64
# 2020_dem_vote_perc      float64
# 2020_lib_vote_count       int64
# 2020_lib_vote_perc      float64
# 2020_grn_vote_count       int64
# 2020_grn_vote_perc      float64
# 2020_oth_vote_count       int64
# 2020_oth_vote_perc      float64
# 2020_votes_total          int64
# 2016_rep_vote_counte      int64
# 2016_rep_vote_perc      float64
# 2016_dem_vote_count       int64
# 2016_dem_vote_perc      float64
# 2016_lib_vote_count       int64
# 2016_lib_vote_perc      float64
# 2016_grn_vote_count       int64
# 2016_grn_vote_perc      float64
# 2016_oth_vote_count       int64
# 2016_oth_vote_perc      float64
# 2016_votes_total          int64
# 2012_rep_vote_perc      float64
# 2012_rep_vote_count       int64
# 2012_dem_vote_perc      float64
# 2012_dem_vote_count       int64
# 2012_oth_vote_perc      float64
# 2012_oth_vote_count       int64
# 2012_vote_total           int64
# 2012_CWPP                 int64
# 2016_CWPP                 int64
# 2020_CWPP                 int64
# dtype: object

# %%
voting_party_data.index.rename('county', inplace=True)

# %%
df = df.merge(right = voting_party_data, how = 'left', left_index = True, right_index = True)

# %%
df.shape
# Out:
# (254, 55)

# %%
df.head()
# Out:
#                  2012_unemp  2016_unemp  2020_unemp  2012_var_state  \
# county
# anderson county       0.036       0.043       0.056          -0.029
# andrews county        0.031       0.047       0.082          -0.034
# angelina county       0.051       0.059       0.076          -0.014
# aransas county        0.068       0.056       0.085           0.003
# archer county         0.034       0.043       0.053          -0.031
#
#                  2016_var_state  2020_var_state  \
# county
# anderson county          -0.005          -0.012
# andrews county           -0.001           0.014
# angelina county           0.011           0.008
# aransas county            0.008           0.017
# archer county            -0.005          -0.015
#
#                  median_income_2012_2016_16_dollars  \
# county
# anderson county                               42146
# andrews county                                70121
# angelina county                               44185
# aransas county                                44851
# archer county                                 62407
#
#                  median_income_2020_16_dollars  2012_reg_voters  \
# county
# anderson county                          44871          26494.0
# andrews county                           69369           8271.0
# angelina county                          47917          49317.0
# aransas county                           49153          15883.0
# archer county                            59010           6322.0
#
#                  2012_voted_num  ...  2012_rep_vote_perc  2012_rep_vote_count  \
# county                           ...
# anderson county         16168.0  ...              0.7564                12262
# andrews county           4478.0  ...              0.8119                 3639
# angelina county         28460.0  ...              0.7147                20303
# aransas county           9646.0  ...              0.7079                 6830
# archer county            4163.0  ...              0.8646                 3600
#
#                  2012_dem_vote_perc  2012_dem_vote_count  2012_oth_vote_perc  \
# county
# anderson county              0.2352                 3813              0.0085
# andrews county               0.1774                  795              0.0107
# angelina county              0.2758                 7834              0.0095
# aransas county               0.2803                 2704              0.0118
# archer county                0.1261                  525              0.0094
#
#                  2012_oth_vote_count  2012_vote_total  2012_CWPP  2016_CWPP  \
# county
# anderson county                  137            16212          0          0
# andrews county                    48             4482          0          0
# angelina county                  269            28406          0          0
# aransas county                   114             9648          0          1
# archer county                     39             4164          0          0
#
#                  2020_CWPP
# county
# anderson county          0
# andrews county           0
# angelina county          0
# aransas county           1
# archer county            1
#
# [5 rows x 55 columns]

# %%
asr = pd.read_csv('./data/asr_12_16_20.csv')

# %%
asr.head()
# Out:
#             county  total_2012_18 to 27  total_2012_28 to 37  \
# 0  anderson county               7387.0               9358.0
# 1   andrews county               2209.0               2050.0
# 2  angelina county              11619.0              10862.0
# 3   aransas county               2353.0               2019.0
# 4    archer county               1022.0                832.0
#
#    total_2012_38 to 47  total_2012_48 to 57  total_2012_58 to 67  \
# 0               9419.0               8915.0               6285.0
# 1               1909.0               2251.0               1473.0
# 2              11243.0              11881.0               9576.0
# 3               2457.0               3557.0               3908.0
# 4               1156.0               1587.0               1111.0
#
#    total_2012_68 to 77  total_2012_78 to 87  total_2012_88 to 97  \
# 0               3832.0               2313.0                  NaN
# 1                884.0                621.0                  NaN
# 2               6062.0               4098.0                  NaN
# 3               3248.0               1753.0                  NaN
# 4                776.0                462.0                  NaN
#
#    total_2016_18 to 27  ...  hispanic_female_2016_78 to 87  \
# 0               7062.0  ...                           36.0
# 1               2450.0  ...                           99.0
# 2              12110.0  ...                          108.0
# 3               2458.0  ...                          130.0
# 4               1213.0  ...                           11.0
#
#    hispanic_female_2016_88 to 97  hispanic_female_2020_18 to 27  \
# 0                            NaN                          633.0
# 1                            NaN                         1054.0
# 2                            NaN                         1654.0
# 3                            NaN                          621.0
# 4                            NaN                           67.0
#
#    hispanic_female_2020_28 to 37  hispanic_female_2020_38 to 47  \
# 0                          466.0                          460.0
# 1                         1131.0                          809.0
# 2                         1335.0                         1337.0
# 3                          596.0                          454.0
# 4                           49.0                           42.0
#
#    hispanic_female_2020_48 to 57  hispanic_female_2020_58 to 67  \
# 0                          360.0                          207.0
# 1                          541.0                          362.0
# 2                          971.0                          666.0
# 3                          410.0                          362.0
# 4                           43.0                           25.0
#
#    hispanic_female_2020_68 to 77  hispanic_female_2020_78 to 87  \
# 0                          153.0                           40.0
# 1                          213.0                           92.0
# 2                          342.0                          123.0
# 3                          243.0                          121.0
# 4                            7.0                           12.0
#
#    hispanic_female_2020_88 to 97
# 0                           20.0
# 1                           30.0
# 2                           30.0
# 3                           31.0
# 4                            5.0
#
# [5 rows x 361 columns]

# %%
asr.set_index('county', inplace = True)

# %%
df = df.merge(right = asr, how = 'left', left_index = True, right_index = True)

# %%
df.head()
# Out:
#                  2012_unemp  2016_unemp  2020_unemp  2012_var_state  \
# county
# anderson county       0.036       0.043       0.056          -0.029
# andrews county        0.031       0.047       0.082          -0.034
# angelina county       0.051       0.059       0.076          -0.014
# aransas county        0.068       0.056       0.085           0.003
# archer county         0.034       0.043       0.053          -0.031
#
#                  2016_var_state  2020_var_state  \
# county
# anderson county          -0.005          -0.012
# andrews county           -0.001           0.014
# angelina county           0.011           0.008
# aransas county            0.008           0.017
# archer county            -0.005          -0.015
#
#                  median_income_2012_2016_16_dollars  \
# county
# anderson county                               42146
# andrews county                                70121
# angelina county                               44185
# aransas county                                44851
# archer county                                 62407
#
#                  median_income_2020_16_dollars  2012_reg_voters  \
# county
# anderson county                          44871          26494.0
# andrews county                           69369           8271.0
# angelina county                          47917          49317.0
# aransas county                           49153          15883.0
# archer county                            59010           6322.0
#
#                  2012_voted_num  ...  hispanic_female_2016_78 to 87  \
# county                           ...
# anderson county         16168.0  ...                           36.0
# andrews county           4478.0  ...                           99.0
# angelina county         28460.0  ...                          108.0
# aransas county           9646.0  ...                          130.0
# archer county            4163.0  ...                           11.0
#
#                  hispanic_female_2016_88 to 97  hispanic_female_2020_18 to 27  \
# county
# anderson county                            NaN                          633.0
# andrews county                             NaN                         1054.0
# angelina county                            NaN                         1654.0
# aransas county                             NaN                          621.0
# archer county                              NaN                           67.0
#
#                  hispanic_female_2020_28 to 37  hispanic_female_2020_38 to 47  \
# county
# anderson county                          466.0                          460.0
# andrews county                          1131.0                          809.0
# angelina county                         1335.0                         1337.0
# aransas county                           596.0                          454.0
# archer county                             49.0                           42.0
#
#                  hispanic_female_2020_48 to 57  hispanic_female_2020_58 to 67  \
# county
# anderson county                          360.0                          207.0
# andrews county                           541.0                          362.0
# angelina county                          971.0                          666.0
# aransas county                           410.0                          362.0
# archer county                             43.0                           25.0
#
#                  hispanic_female_2020_68 to 77  hispanic_female_2020_78 to 87  \
# county
# anderson county                          153.0                           40.0
# andrews county                           213.0                           92.0
# angelina county                          342.0                          123.0
# aransas county                           243.0                          121.0
# archer county                              7.0                           12.0
#
#                  hispanic_female_2020_88 to 97
# county
# anderson county                           20.0
# andrews county                            30.0
# angelina county                           30.0
# aransas county                            31.0
# archer county                              5.0
#
# [5 rows x 415 columns]

# %%
df.shape
# Out:
# (254, 415)

# %%
df.to_csv('combined_df.csv')
